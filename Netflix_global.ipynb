# %% [markdown]
# #### Datos de Visualizaciones de Netflix

# %%
import pandas as pd
import numpy as np

data = pd.read_excel("all-weeks-global.xlsx")
data
# Out:
#             week          category  weekly_rank                   show_title  \
# 0     2023-12-10   Films (English)            1       Leave the World Behind
# 1     2023-12-10   Films (English)            2                Family Switch
# 2     2023-12-10   Films (English)            3                          Leo
# 3     2023-12-10   Films (English)            4  The Super Mario Bros. Movie
# 4     2023-12-10   Films (English)            5           Catering Christmas
# ...          ...               ...          ...                          ...
# 5115  2021-07-04  TV (Non-English)            6                        Elite
# 5116  2021-07-04  TV (Non-English)            7                        Elite
# 5117  2021-07-04  TV (Non-English)            8                        Elite
# 5118  2021-07-04  TV (Non-English)            9                        Katla
# 5119  2021-07-04  TV (Non-English)           10           Record of Ragnarok
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5120 entries, 0 to 5119
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   week                        5120 non-null   object
#  1   category                    5120 non-null   object
#  2   weekly_rank                 5120 non-null   int64
#  3   show_title                  5120 non-null   object
#  4   season_title                2479 non-null   object
#  5   weekly_hours_viewed         5120 non-null   int64
#  6   runtime                     1040 non-null   float64
#  7   weekly_views                1040 non-null   float64
#  8   cumulative_weeks_in_top_10  5120 non-null   int64
#  9   is_staggered_launch         5120 non-null   bool
#  10  episode_launch_details      38 non-null     object
# dtypes: bool(1), float64(2), int64(3), object(5)
# memory usage: 405.1+ KB

# %%
horasem = data.sort_values(by='weekly_hours_viewed', ascending=False)
horasem.head(15)
# Out:
#             week          category  weekly_rank          show_title  \
# 4590  2021-10-03  TV (Non-English)            1          Squid Game
# 4630  2021-09-26  TV (Non-English)            1          Squid Game
# 4550  2021-10-10  TV (Non-English)            1          Squid Game
# 2140  2022-12-04      TV (English)            1           Wednesday
# 2180  2022-11-27      TV (English)            1           Wednesday
# 3180  2022-06-05      TV (English)            1     Stranger Things
# 3020  2022-07-03      TV (English)            1     Stranger Things
# 2500  2022-10-02      TV (English)            1              DAHMER
# 3220  2022-05-29      TV (English)            1     Stranger Things
# 2100  2022-12-11      TV (English)            1           Wednesday
# 4510  2021-10-17  TV (Non-English)            1          Squid Game
# 3540  2022-04-03      TV (English)            1          Bridgerton
# 3870  2022-02-06  TV (Non-English)            1  All of Us Are Dead
# ...

# %%
vistasem = data.sort_values(by='weekly_views', ascending=False)
vistasem.head(15)
# Out:
#             week             category  weekly_rank              show_title  \
# 1000  2023-06-18      Films (English)            1            Extraction 2
# 960   2023-06-25      Films (English)            1            Extraction 2
# 0     2023-12-10      Films (English)            1  Leave the World Behind
# 640   2023-08-20      Films (English)            1          Heart of Stone
# 80    2023-11-26      Films (English)            1                     Leo
# 680   2023-08-13      Films (English)            1          Heart of Stone
# 370   2023-10-08  Films (Non-English)            1                 Nowhere
# 840   2023-07-16      Films (English)            1            The Out-Laws
# 160   2023-11-12      Films (English)            1              The Killer
# 410   2023-10-01  Films (Non-English)            1                 Nowhere
# 720   2023-08-06      Films (English)            1           Hidden Strike
# ...

# %%
vistasem = vistasem.drop_duplicates(subset='show_title', keep='first')
vistasem.head(10)
# Out:
#             week             category  weekly_rank  \
# 1000  2023-06-18      Films (English)            1
# 0     2023-12-10      Films (English)            1
# 640   2023-08-20      Films (English)            1
# 80    2023-11-26      Films (English)            1
# 370   2023-10-08  Films (Non-English)            1
# 840   2023-07-16      Films (English)            1
# 160   2023-11-12      Films (English)            1
# 720   2023-08-06      Films (English)            1
# 41    2023-12-03      Films (English)            2
# 560   2023-09-03      Films (English)            1
#
#                                     show_title season_title  \
# 1000                              Extraction 2          NaN
# 0                       Leave the World Behind          NaN
# 640                             Heart of Stone          NaN
# 80                                         Leo          NaN
# 370                                    Nowhere          NaN
# ...

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# Calcular los pesos de las palabras basados en los valores numéricos
weights = dict(zip(vistasem['show_title'], vistasem['weekly_views']))
# Crear la nube de palabras
wc = WordCloud(width = 1000, height = 300, background_color='black', colormap = "Reds").generate_from_frequencies(weights)

# Mostrar la nube de palabras
plt.imshow(wc, interpolation='bilinear')
plt.axis('off')

# Guardar la nube de palabras
#wc.to_file("VistasSemanales.png")
# Out:
# (-0.5, 999.5, 299.5, -0.5)

# %%
horasem = horasem.drop_duplicates(subset='show_title', keep='first')
horasem.head(10)
# Out:
#             week          category  weekly_rank          show_title  \
# 4590  2021-10-03  TV (Non-English)            1          Squid Game
# 2140  2022-12-04      TV (English)            1           Wednesday
# 3180  2022-06-05      TV (English)            1     Stranger Things
# 2500  2022-10-02      TV (English)            1              DAHMER
# 3540  2022-04-03      TV (English)            1          Bridgerton
# 3870  2022-02-06  TV (Non-English)            1  All of Us Are Dead
# 1460  2023-04-02      TV (English)            1     The Night Agent
# 4750  2021-09-05  TV (Non-English)            1         Money Heist
# 3780  2022-02-20      TV (English)            1      Inventing Anna
# 1940  2023-01-08      TV (English)            1     Ginny & Georgia
#
#                                    season_title  weekly_hours_viewed  runtime  \
# 4590                       Squid Game: Season 1            571760000      NaN
# ...

# %%
#Preparar la Nube
weights1 = dict(zip(horasem['show_title'], horasem['weekly_hours_viewed']))
wc1 = WordCloud(width = 1000, height = 300, background_color='black', colormap = "Reds").generate_from_frequencies(weights1)

# Mostrar la nube de palabras
plt.imshow(wc1, interpolation='bilinear')
plt.axis('off')

# Guardar la nube de palabras
#wc1.to_file("HorasSemanalesVistas.png")
# Out:
# (-0.5, 999.5, 299.5, -0.5)
